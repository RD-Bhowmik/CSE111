# %%
#Problem-01
class Calculator:
        def __init__(self):
                print("Let's Calculate!")
        def add(self, first_val, second_val):
            result = first_val + second_val
            print("Result: " + str(result))
        def subtract(self, first_val, second_val):
            result = first_val - second_val
            print("Result: " + str(result))
        def multiply(self, first_val, second_val):
            result = first_val * second_val
            print("Result: " + str(result))
        def divide(self, first_val, second_val):
            if second_value == 0:
                return     
            result = first_val / second_val
            print("Result: " + str(result))
obj = Calculator()
first_val = int(input("Value 1: "))
operator = input("Operator: ")
second_val = int(input("Value 2: "))
if operator == '+':
    obj.add(first_val, second_val)
elif operator == '-':
    obj.subtract(first_val, second_val)
elif operator == '*':
    obj.multiply(first_val, second_val)
elif operator == '/':
    obj.divide(first_val, second_val)
else:
    print("You entered a incorrect operator")
# Out:
# Let's Calculate!
# Value 1: 1
# Operator: +
# Value 2: 2
# Result: 3

# %%
#Problem-02
class Customer:
    def __init__(self, name):
        self.name = name
    def greet(self, name=None):
        print("Hello!")
    def purchase(self, *args):
        print(str(self.name)+", you purchase "+str(len(args))+" item(s):")
        for i in args:
            print(i)
customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet()
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam, you purchase 3 item(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello!
# David, you purchase 1 item(s):
# orange juice

# %%
#Problem-03
class Panda:
    name=""
    gender=""
    age=0
    def __init__(self,name,gender,age):
        self.name=name
        self.gender=gender
        self.age=age
    def sleep(self,time=None):
        if(time==None):  
            st=self.name+"'s duration is unknown thus should have only bamboo leaves"
        else:
            st=self.name+" sleeps "+str(time)+" hours daily and should have "
            if(time>=3 and time<=5):   
                st=st+"Mixed Veggies"
            elif(time>=6 and time <=8): 
                st=st+"Eggplant & Tofu"
            elif(time>=9 and time<=11): 
                st=st+"Broccoli Chicken"
        return st
panda1=Panda("Kunfu","Male",5)
panda2=Panda("Pan Pan","Female",3)
panda3=Panda("Ming Ming","Female",8)
print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))
print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))
print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))
print("===========================")
print(panda2.sleep(10))
print(panda1.sleep(4))
print(panda3.sleep())
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming's duration is unknown thus should have only bamboo leaves

# %%
#Problem-04
class Cat:
    def __init__(self, color=None, action=None):
        if color is None:
            self.color = "White"
        else:
            self.color = color
        if action is None:
            self.action = "sitting"
        else:
            self.action = action
    def changeColor(self,color):
        self.color = color
    def printCat(self):
        print(self.color + " cat is " + self.action)
c1 = Cat()
c2 = Cat('Black')
c3 = Cat('Brown','jumping')
c4 = Cat('Red','purring')
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor('Blue')
c3.changeColor('Purple')
c1.printCat()
c3.printCat()
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#Problem-05
class Student:
    def __init__(self, name = 'default student'): 
        self.name = name
        self.marks = 0.0
    def quizcalc(self, quiz1 = 0, quiz2 = 0, quiz3 = 0): 
        self.marks = (quiz1 + quiz2 + quiz3)/3
    def printdetail(self): 
        print('Hello ' + self.name)
        print('Your Average score is ', self.marks)
s1 = Student() 
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail() 
s2 = Student('Harry')
s2.quizcalc(10, 8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10, 9, 10)
print('--------------------------------')
s3.printdetail()
# Out:
# --------------------------------
# Hello default student
# Your Average score is  3.3333333333333335
# --------------------------------
# Hello Harry
# Your Average score is  6.0
# --------------------------------
# Hello Hermione
# Your Average score is  9.666666666666666

# %%
#Problem-06
class Vehicle:
    def __init__(self):
        self.x = 0
        self.y = 0
    def moveUp(self):
        self.y = self.y+1
    def moveLeft(self):
        self.x = self.x-1
    def moveDown(self):
        self.y = self.y -1
    def moveRight(self):
        self.x = self.x+1   
    def print_position(self):
        print("("+str(self.x)+" "+str(self.y)+")")
car =Vehicle() 
car.print_position()
car.moveUp()
car.print_position()
car.moveLeft()
car.print_position()
car.moveDown()
car.print_position()
car.moveRight()
# Out:
# (0 0)
# (0 1)
# (-1 1)
# (-1 0)

# %%
#Problem-07
class Programmer:
    def __init__(self, name, lang, exp):
        self.name = name
        self.lang = lang
        self.exp = exp
        print('Horray! A new programmer is born')
    def addExp(self,exp):
        self.exp += exp
        print('Updating experiance for',self.name)
    def printDetails(self):
        print('Name:',self.name)
        print('Language:',self.lang)
        print('Experiance:',self.exp,'years')
if __name__ == "__main__":
    p1 = Programmer("Ethan Hunt","Java",10)
    p1.printDetails()
    print('--------------------------')
    p2 = Programmer("James Bond","C++",7)
    p2.printDetails()
    print('--------------------------')
    p3 = Programmer("Jon Snow","Python",4)
    p3.printDetails()
    p3.addExp(5)
    p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name: Ethan Hunt
# Language: Java
# Experiance: 10 years
# --------------------------
# Horray! A new programmer is born
# Name: James Bond
# Language: C++
# Experiance: 7 years
# --------------------------
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experiance: 4 years
# Updating experiance for Jon Snow
# Name: Jon Snow
# Language: Python
# Experiance: 9 years

# %%
#Problem-08
class Student:
    def __init__(self, name="", ID=0, dept="CSE"):
        self.__name = name
        self.__ID = ID
        self.__dept = dept
        self.__hours = 0
    def dailyEffort(self, hours):
        self.__hours = hours
    def printDetails(self):
        print("Name:", self.__name)
        print("ID:", self.__ID)
        print("Department:", self.__dept)
        print("Daily Effort:", self.__hours, "hour(s)")
        if self.__hours <= 2:
            print("Suggestion: Should give more effort!")
        elif self.__hours <= 4:
            print("Suggestion: Keep up the good work!")
        else:
            print("Suggestion: Excellent! Now motivate others.")
harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# ID: 123
# Department: CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ...
# Name: John Wick
# ID: 456
# Department: BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ...
# Name: Naruto Uzumaki
# ID: 777
# Department: Ninja
# Daily Effort: 6 hour(s)
# Suggestion: Excellent! Now motivate others.

# %%
#Problem-09
class Patient:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.symptoms = []
    def add_Symptom(self, *args):
        for i in args:
            self.symptoms.append(i)
                                                        #for printing the patient detail
    def printPatientDetail(self):
        print("Name: {}".format(self.name))
        print("Age: {}".format(self.age))
        print("Symptoms: ", end="")
        print(", ".join(self.symptoms))
p1 = Patient("Thomas", 23)
p1.add_Symptom("Headache")
p2 = Patient("Carol", 20)
p2.add_Symptom("Vomiting", "Coughing")
p3 = Patient("Mike", 25)
p3.add_Symptom("Fever", "Headache", "Coughing")
print("=========================")
p1.printPatientDetail()
print("=========================")
p2.printPatientDetail()
print("=========================")
p3.printPatientDetail()
# Out:
# ...
# Name: Thomas
# Age: 23
# Symptoms: Headache
# ...
# Name: Carol
# Age: 20
# Symptoms: Vomiting, Coughing
# ...
# Name: Mike
# Age: 25
# Symptoms: Fever, Headache, Coughing

# %%
#Problem-10
class Avengers:
    def __init__(self,name,mate):
        self.name=name
        self.mate=mate
        self.powers=[] 
    def super_powers(self,*argv):
        for i in argv:
            self.powers.append(i)     
    def printAvengersDetail(self):
        print("Name:",self.name)
        print("Partner:",self.mate)
        print("Super Powers:",(str(self.powers)[1:-1]))
a1=Avengers('Captain America','Bucky Barnes')
a1.super_powers('Stamina','Slowed ageing')
a2=Avengers('Doctor Strange','Ancient One')
a2.super_powers('Mastery of Magic')
a3=Avengers('Iron Man','War Machine')
a3.super_powers('Genious level intellect','Scientist')
print("=================================")
a1.printAvengersDetail()
print("=================================")
a2.printAvengersDetail()
print("=================================")
a3.printAvengersDetail()
print("=================================")
# Out:
# ...
# Name: Captain America
# Partner: Bucky Barnes
# Super Powers: 'Stamina', 'Slowed ageing'
# ...
# Name: Doctor Strange
# Partner: Ancient One
# Super Powers: 'Mastery of Magic'
# ...
# Name: Iron Man
# Partner: War Machine
# Super Powers: 'Genious level intellect', 'Scientist'
# ...

# %%
#Problem-11
class Shinobi:
    def __init__(self, name, rank):
        self.name = name
        self.rank = rank
        self.salary = 0
        self.mission = 0
    def changeRank(self, new_rank):
        self.rank = new_rank
    def calSalary(self, new_mission):
        self.mission = new_mission
        if self.rank == 'Genin':
            self.salary = self.mission * 50
        elif self.rank == 'Chunin':
            self.salary = self.mission * 100
        else:
            self.salary = self.mission * 500
    def printInfo(self):
        print('Name: ', self.name)
        print('Rank: ', self.rank)
        print('Number of mission: ', self.mission)
        print('Salary: ', self.salary)
if __name__ == '__main__':
    naruto = Shinobi('Naruto', 'Genin')
    naruto.calSalary(5)
    naruto.printInfo()
    print('====================')
    shikarmaru = Shinobi('Shikamaru', 'Genin')
    shikarmaru.printInfo()
    shikarmaru.changeRank('Chunin')
    shikarmaru.calSalary(10)
    shikarmaru.printInfo()
    print('====================')
    neiji = Shinobi('Neiji', 'Jonin')
    neiji.calSalary(5)
    neiji.printInfo()
# Out:
# Name:  Naruto
# Rank:  Genin
# Number of mission:  5
# Salary:  250
# ...
# Name:  Shikamaru
# Rank:  Genin
# Number of mission:  0
# Salary:  0
# Name:  Shikamaru
# Rank:  Chunin
# Number of mission:  10
# Salary:  1000
# ...
# Name:  Neiji
# Rank:  Jonin
# Number of mission:  5
# Salary:  2500

# %%
#problem-12
class ParcelKoro:
    def __init__(self, name = 'No name set', weight = 0):
        self.name = name
        self.product_weight = weight
        self.total_fee = 0
    def calculateFee(self, deliv_loc = ''):
        if deliv_loc == '':
            loc_charge = 50
        else:
            loc_charge = 100
        if self.product_weight == 0:
            self.total_fee = 0
        else:
            self.total_fee = (self.product_weight * 20) + loc_charge
    def printDetails(self):
        print('Customer Name:', self.name)
        print('Product Weight:', self.product_weight)
        print('Total fee:', self.total_fee)
print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")   
p2.product_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro('Dora The Explorer', 10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# Out:
# **********************
# Customer Name: No name set
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# ----------------------------
# Customer Name: Bob The Builder
# Product Weight: 15
# Total fee: 350
# **********************
# Customer Name: Dora The Explorer
# Product Weight: 10
# Total fee: 300

# %%
#Problem-13
class Batsman:
    def __init__(self, *args): 
        if isinstance(args[0], int): 
            self.name = "New Batsman" 
            self.runs = args[0] 
            self.balls = args[1] 
        elif isinstance(args[0], str): 
            self.name = args[0] 
            self.runs = args[1] 
            self.balls = args[2] 
    def printCareerStatistics(self):
        print("Name:", self.name)
        print("Runs Scored:", self.runs, ", Balls Faced:", self.balls)  
    def setName(self, name):
        self.name = name
    def battingStrikeRate(self):
        return (self.runs/self.balls) * 100
b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scored: 6101 , Balls Faced: 7380
# ...
# Name: Liton Das
# Runs Scored: 678 , Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ...
# Name: Shakib Al Hasan
# Runs Scored: 6101 , Balls Faced: 7380
# ----------------------------
# 82.66937669376694

# %%
#Problem-14
class EPL_Team:
    def __init__(self,name,*args):
        self.name=name
        if len(args)>0:
            self.song=args[0]
        else:
            self.song='No Slogan'
        self.title=0
    def showClubInfo(self):
        return("Name: %s\nSong: %s\nTotal No of title: %d"%(self.name,self.song,self.title))
    def increaseTitle(self):
        self.title=self.title+1
    def changeSong(self,song):
        self.song=song
if __name__=="__main__":
    manu=EPL_Team('Manchester United','Glory Glory Man United')
    chelsea=EPL_Team('Chelsea')
    print('===================')
    print(manu.showClubInfo())
    print('##################')
    manu.increaseTitle()
    print(manu.showClubInfo())
    print('===================')
    print(chelsea.showClubInfo())
    chelsea.changeSong('Keep the blue flag flying high')
    print(chelsea.showClubInfo())
# Out:
# ...
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 0
# ##################
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 1
# ...
# Name: Chelsea
# Song: No Slogan
# Total No of title: 0
# Name: Chelsea
# Song: Keep the blue flag flying high
# Total No of title: 0

# %%
#Problem-15
class Account():
    def __init__(self, name='Default Account', balance=0.0):
        self.name = name
        self.balance = balance
    def details(self):
        return f'{self.name}\n{self.balance}'
    def withdraw(self, amount):
        if amount > self.balance:
            print('Sorry, Withdraw unsucessful!.The account')
            print('balance after deducting withdraw amount is')
            print('equal to or less than minimum.')
        else:
            self.balance -= amount
            print('Withdraw successful! New balance is', self.balance)
a1 = Account()
print(a1.details())
print("------------------------")
a1.name = 'Oliver'
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account('Liam')
print(a2.details())
print("------------------------")
a3 = Account('Noah', 400)
print(a3.details())
print("------------------------")
a2.withdraw(6930)
print("------------------------")
a2.withdraw(600)
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400
# ------------------------
# Sorry, Withdraw unsucessful!.The account
# balance after deducting withdraw amount is
# equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsucessful!.The account
# balance after deducting withdraw amount is
# equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is 3071.0

# %%
#Problem-16
class Author:
    def __init__(self, name="Default", *books):
        self.name = name
        self.books = []
        for book in books:
            self.books.append(book)
    def addBooks(self, *books):
        for book in books:
            self.books.append(book)
    def changeName(self, name):
        self.name = name
    def printDetails(self):
        print("Author Name:", self.name)
        print("-------")
        print("List of Books:")
        for book in self.books:
            print(book)
auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name: Humayun Ahmed
# -------
# List of Books:
# Deyal
# Megher Opor Bari
# ...
# Default
# ...
# Author Name: Mario Puzo
# -------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ...
# Author Name: Paolo Coelho
# -------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#Problem-17
